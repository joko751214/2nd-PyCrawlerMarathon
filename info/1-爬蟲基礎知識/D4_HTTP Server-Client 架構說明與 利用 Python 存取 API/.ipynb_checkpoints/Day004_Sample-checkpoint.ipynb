# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11622350737","type":"PushEvent","actor":{"id":28583588,"login":"yerinoh","display_login":"yerinoh","gravatar_id":"","url":"https://api.github.com/users/yerinoh","avatar_url":"https://avatars.githubusercontent.com/u/28583588?"},"repo":{"id":240416206,"name":"sonhyeongi/KMU_capstone_2020","url":"https://api.github.com/repos/sonhyeongi/KMU_capstone_2020"},"payload":{"push_id":4688360703,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7e021159957a38e11720f50bc84418fd4fc3f211","before":"d4fab3124ee39e2a08fbe202b2395311ec1881f2","commits":[{"sha":"7e021159957a38e11720f50bc84418fd4fc3f211","author":{"email":"yerinoh@kookmin.ac.kr","name":"yerinfive"},"message":"Delete ㅁ","distinct":true,"url":"https://api.github.com/repos/sonhyeongi/KMU_capstone_2020/commits/7e021159957a38e11720f50bc84418fd4fc3f211"}]},"public":true,"created_at":"2020-02-27T06:13:47Z"},{"id":"11622350738","type":"WatchEvent","actor":{"id":1238927,"login":"jasonmelton","display_login":"jasonmelton","gravatar_id":"","url":"https://api.github.com/users/jasonmelton","avatar_url":"https://avatars.githubusercontent.com/u/1238927?"},"repo":{"id":193162629,"name":"rxhanson/Rectangle","url":"https://api.github.com/repos/rxhanson/Rectangle"},"payload":{"action":"started"},"public":true,"created_at":"2020-02-27T06:13:47Z"},{"id":"11622350723","type":"PushEvent","actor":{"id":60985479,"login":"Anik055-hub","display_login":"Anik055-hub","gravatar_id":"","url":"https://api.github.com/users/Anik055-hub","avatar_url":"https://avatars.githubusercontent.com/u/60985479?"},"repo":{"id":243444049,"name":"Anik055-hub/midlabexam","url":"https://api.github.com/repos/Anik055-hub/midlabexam"},"payload":{"push_id":4688360698,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"02f463ea4a7a03a2b3913f13c696505cb29658c8","before":"7a48853164390943546eb8f32aaaafd8420f2f86","commits":[{"sha":"02f463ea4a7a03a2b3913f13c696505cb29658c8","author":{"email":"rasel5jkibria@gmail.com","name":"rasel3780"},"message":"first commit","distinct":true,"url":"https://api.github.com/repos/Anik055-hub/midlabexam/commits/02f463ea4a7a03a2b3913f13c696505cb29658c8"}]},"public":true,"created_at":"2020-02-27T06:13:47Z"},{"id":"11622350718","type":"PushEvent","actor":{"id":34895636,"login":"afewellvmware","display_login":"afewellvmware","gravatar_id":"","url":"https://api.github.com/users/afewellvmware","avatar_url":"https://avatars.githubusercontent.com/u/34895636?"},"repo":{"id":242284059,"name":"kampfires/kubefeed","url":"https://api.github.com/repos/kampfires/kubefeed"},"payload":{"push_id":4688360702,"size":1,"distinct_size":1,"ref":"refs/heads/rmformsvc","head":"23c8bfd7eac097e34ff85b88037814eba5b13586","before":"cc5b6f96ba7b7fef5ece85bdfbaf2530622ba6a7","commits":[{"sha":"23c8bfd7eac097e34ff85b88037814eba5b13586","author":{"email":"jenkins-x@googlegroups.com","name":"jenkins-x-bot"},"message":"test","distinct":true,"url":"https://api.github.com/repos/kampfires/kubefeed/commits/23c8bfd7eac097e34ff85b88037814eba5b13586"}]},"public":true,"created_at":"2020-02-27T06:13:47Z","org":{"id":60899626,"login":"kampfires","gravatar_id":"","url":"https://api.github.com/orgs/kampfires","avatar_url":"https://avatars.githubusercontent.com/u/60899626?"}},{"id":"11622350692","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":243441482,"name":"SakshamSehrawet/try","url":"https://api.github.com/repos/SakshamSehrawet/try"},"payload":{"action":"opened","number":4,"pull_request":{"url":"https://api.github.com/repos/SakshamSehrawet/try/pulls/4","id":380657358,"node_id":"MDExOlB1bGxSZXF1ZXN0MzgwNjU3MzU4","html_url":"https://github.com/SakshamSehrawet/try/pull/4","diff_url":"https://github.com/SakshamSehrawet/try/pull/4.diff","patch_url":"https://github.com/SakshamSehrawet/try/pull/4.patch","issue_url":"https://ap ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11622350737',
#   'type': 'PushEvent',
#   'actor': {'id': 28583588,
#    'login': 'yerinoh',
#    'display_login': 'yerinoh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yerinoh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28583588?'},
#   'repo': {'id': 240416206,
#    'name': 'sonhyeongi/KMU_capstone_2020',
#    'url': 'https://api.github.com/repos/sonhyeongi/KMU_capstone_2020'},
#   'payload': {'push_id': 4688360703,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7e021159957a38e11720f50bc84418fd4fc3f211',
#    'before': 'd4fab3124ee39e2a08fbe202b2395311ec1881f2',
#    'commits': [{'sha': '7e021159957a38e11720f50bc84418fd4fc3f211',
#      'author': {'email': 'yerinoh@kookmin.ac.kr', 'name': 'yerinfive'},
#      'message': 'Delete ㅁ',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sonhyeongi/KMU_capstone_2020/commits/7e021159957a38e11720f50bc84418fd4fc3f211'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:47Z'},
#  {'id': '11622350738',
#   'type': 'WatchEvent',
#   'actor': {'id': 1238927,
#    'login': 'jasonmelton',
#    'display_login': 'jasonmelton',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jasonmelton',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1238927?'},
#   'repo': {'id': 193162629,
#    'name': 'rxhanson/Rectangle',
#    'url': 'https://api.github.com/repos/rxhanson/Rectangle'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-27T06:13:47Z'},
#  {'id': '11622350723',
#   'type': 'PushEvent',
#   'actor': {'id': 60985479,
#    'login': 'Anik055-hub',
#    'display_login': 'Anik055-hub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anik055-hub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60985479?'},
#   'repo': {'id': 243444049,
#    'name': 'Anik055-hub/midlabexam',
#    'url': 'https://api.github.com/repos/Anik055-hub/midlabexam'},
#   'payload': {'push_id': 4688360698,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '02f463ea4a7a03a2b3913f13c696505cb29658c8',
#    'before': '7a48853164390943546eb8f32aaaafd8420f2f86',
#    'commits': [{'sha': '02f463ea4a7a03a2b3913f13c696505cb29658c8',
#      'author': {'email': 'rasel5jkibria@gmail.com', 'name': 'rasel3780'},
#      'message': 'first commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Anik055-hub/midlabexam/commits/02f463ea4a7a03a2b3913f13c696505cb29658c8'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:47Z'},
#  {'id': '11622350718',
#   'type': 'PushEvent',
#   'actor': {'id': 34895636,
#    'login': 'afewellvmware',
#    'display_login': 'afewellvmware',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afewellvmware',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34895636?'},
#   'repo': {'id': 242284059,
#    'name': 'kampfires/kubefeed',
#    'url': 'https://api.github.com/repos/kampfires/kubefeed'},
#   'payload': {'push_id': 4688360702,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/rmformsvc',
#    'head': '23c8bfd7eac097e34ff85b88037814eba5b13586',
#    'before': 'cc5b6f96ba7b7fef5ece85bdfbaf2530622ba6a7',
#    'commits': [{'sha': '23c8bfd7eac097e34ff85b88037814eba5b13586',
#      'author': {'email': 'jenkins-x@googlegroups.com',
#       'name': 'jenkins-x-bot'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kampfires/kubefeed/commits/23c8bfd7eac097e34ff85b88037814eba5b13586'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:47Z',
#   'org': {'id': 60899626,
#    'login': 'kampfires',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kampfires',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60899626?'}},
#  {'id': '11622350692',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 243441482,
#    'name': 'SakshamSehrawet/try',
#    'url': 'https://api.github.com/repos/SakshamSehrawet/try'},
#   'payload': {'action': 'opened',
#    'number': 4,
#    'pull_request': {'url': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/4',
#     'id': 380657358,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgwNjU3MzU4',
#     'html_url': 'https://github.com/SakshamSehrawet/try/pull/4',
#     'diff_url': 'https://github.com/SakshamSehrawet/try/pull/4.diff',
#     'patch_url': 'https://github.com/SakshamSehrawet/try/pull/4.patch',
#     'issue_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues/4',
#     'number': 4,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump flask from 0.8 to 1.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "Bumps [flask](https://github.com/pallets/flask) from 0.8 to 1.0.\n<details>\n<summary>Release notes</summary>\n\n*Sourced from [flask's releases](https://github.com/pallets/flask/releases).*\n\n> ## 1.0\n> The Pallets team is pleased to release Flask 1.0. [Read the announcement on our blog.](https://www.palletsprojects.com/blog/flask-1-0-released/\r\n> \r\n> There are over a year's worth of changes in this release. Many features have been improved or changed. [Read the changelog](http://flask.pocoo.org/docs/1.0/changelog/) to understand how your project's code will be affected.\r\n> \r\n> \r\n> JSON Security Fix\r\n> ------------------\r\n> \r\n> Flask previously decoded incoming JSON bytes using the content type of the request. Although JSON should only be encoded as UTF-8, Flask was more lenient. However, Python includes non-text related encodings that could result in unexpected memory use by a request.\r\n> \r\n> Flask will now detect the encoding of incoming JSON data as one of the supported UTF encodings, and will not allow arbitrary encodings from the request.\r\n> \r\n> \r\n> Install or Upgrade\r\n> -------------------\r\n> \r\n> Install from [PyPI](https://pypi.org/project/Flask/) with pip:\r\n> \r\n>     pip install -U Flask\n> \n> ## 0.12.4\n> This is a repackage of [0.12.3](https://github.com/pallets/flask/releases/0.12.3) to fix an issue with how the package was built.\r\n> \r\n> \r\n> Upgrade\r\n> --------\r\n> \r\n> Upgrade from [PyPI](https://pypi.org/project/Flask/0.12.4/) with pip. Use a version identifier if you want to stay at 0.12:\r\n> \r\n>     pip install -U 'Flask~=0.12.4'\r\n> \n> ## 0.12.3\n> This release includes an important security fix for JSON and a minor backport for CLI support in PyCharm. It is provided for projects that cannot update to Flask 1.0 immediately. See the [1.0 announcement](https://github.com/pallets/flask/blob/flask-1-0-released) and update to it instead if possible.\r\n> \r\n> \r\n> JSON Security Fix\r\n> ------------------\r\n> \r\n> Flask previously decoded incoming JSON bytes using the content type of the request. Although JSON should only be encoded as UTF-8, Flask was more lenient. However, Python includes non-text related encodings that could result in unexpected memory use by a request.\r\n> \r\n> Flask will now detect the encoding of incoming JSON data as one of the supported UTF encodings, and will not allow arbitrary encodings from the request.\r\n> \r\n> \r\n> Upgrade\r\n> --------\r\n> \r\n> Upgrade from [PyPI](https://pypi.org/project/Flask/) with pip. Use a version identifier if you want to stay at 0.12:\r\n> \r\n>     pip install -U 'Flask~=0.12.3'\r\n></tr></table> ... (truncated)\n</details>\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [flask's changelog](https://github.com/pallets/flask/blob/master/CHANGES.rst).*\n\n> Version 1.0\n> -----------\n> \n> Released 2018-04-26\n> \n> -   Python 2.6 and 3.3 are no longer supported.\n> -   Bump minimum dependency versions to the latest stable versions:\n>     Werkzeug >= 0.14, Jinja >= 2.10, itsdangerous >= 0.24, Click >= 5.1.\n>     :issue:`2586`\n> -   Skip :meth:`app.run <Flask.run>` when a Flask application is run\n>     from the command line. This avoids some behavior that was confusing\n>     to debug.\n> -   Change the default for :data:`JSONIFY_PRETTYPRINT_REGULAR` to\n>     ``False``. :func:`~json.jsonify` returns a compact format by\n>     default, and an indented format in debug mode. :pr:`2193`\n> -   :meth:`Flask.__init__ <Flask>` accepts the ``host_matching``\n>     argument and sets it on :attr:`~Flask.url_map`. :issue:`1559`\n> -   :meth:`Flask.__init__ <Flask>` accepts the ``static_host`` argument\n>     and passes it as the ``host`` argument when defining the static\n>     route. :issue:`1559`\n> -   :func:`send_file` supports Unicode in ``attachment_filename``.\n>     :pr:`2223`\n> -   Pass ``_scheme`` argument from :func:`url_for` to\n>     :meth:`~Flask.handle_url_build_er ...
#     'created_at': '2020-02-27T06:13:46Z',
#     'updated_at': '2020-02-27T06:13:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/4/commits',
#     'review_comments_url': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/4/comments',
#     'review_comment_url': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues/4/comments',
#     'statuses_url': 'https://api.github.com/repos/SakshamSehrawet/try/statuses/bf0050198a99e5bc256eb0d8c6478f2f4d49f8a7',
#     'head': {'label': 'SakshamSehrawet:dependabot/pip/flask-1.0',
#      'ref': 'dependabot/pip/flask-1.0',
#      'sha': 'bf0050198a99e5bc256eb0d8c6478f2f4d49f8a7',
#      'user': {'login': 'SakshamSehrawet',
#       'id': 24732526,
#       'node_id': 'MDQ6VXNlcjI0NzMyNTI2',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/24732526?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SakshamSehrawet',
#       'html_url': 'https://github.com/SakshamSehrawet',
#       'followers_url': 'https://api.github.com/users/SakshamSehrawet/followers',
#       'following_url': 'https://api.github.com/users/SakshamSehrawet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SakshamSehrawet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SakshamSehrawet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SakshamSehrawet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SakshamSehrawet/orgs',
#       'repos_url': 'https://api.github.com/users/SakshamSehrawet/repos',
#       'events_url': 'https://api.github.com/users/SakshamSehrawet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SakshamSehrawet/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 243441482,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDM0NDE0ODI=',
#       'name': 'try',
#       'full_name': 'SakshamSehrawet/try',
#       'private': False,
#       'owner': {'login': 'SakshamSehrawet',
#        'id': 24732526,
#        'node_id': 'MDQ6VXNlcjI0NzMyNTI2',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/24732526?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SakshamSehrawet',
#        'html_url': 'https://github.com/SakshamSehrawet',
#        'followers_url': 'https://api.github.com/users/SakshamSehrawet/followers',
#        'following_url': 'https://api.github.com/users/SakshamSehrawet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SakshamSehrawet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SakshamSehrawet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SakshamSehrawet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SakshamSehrawet/orgs',
#        'repos_url': 'https://api.github.com/users/SakshamSehrawet/repos',
#        'events_url': 'https://api.github.com/users/SakshamSehrawet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SakshamSehrawet/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SakshamSehrawet/try',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/SakshamSehrawet/try',
#       'forks_url': 'https://api.github.com/repos/SakshamSehrawet/try/forks',
#       'keys_url': 'https://api.github.com/repos/SakshamSehrawet/try/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SakshamSehrawet/try/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SakshamSehrawet/try/teams',
#       'hooks_url': 'https://api.github.com/repos/SakshamSehrawet/try/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SakshamSehrawet/try/events',
#       'assignees_url': 'https://api.github.com/repos/SakshamSehrawet/try/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SakshamSehrawet/try/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SakshamSehrawet/try/tags',
#       'blobs_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SakshamSehrawet/try/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SakshamSehrawet/try/languages',
#       'stargazers_url': 'https://api.github.com/repos/SakshamSehrawet/try/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SakshamSehrawet/try/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SakshamSehrawet/try/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SakshamSehrawet/try/subscription',
#       'commits_url': 'https://api.github.com/repos/SakshamSehrawet/try/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SakshamSehrawet/try/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SakshamSehrawet/try/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SakshamSehrawet/try/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SakshamSehrawet/try/merges',
#       'archive_url': 'https://api.github.com/repos/SakshamSehrawet/try/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/SakshamSehrawet/try/downloads',
#       'issues_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/SakshamSehrawet/try/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/SakshamSehrawet/try/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/SakshamSehrawet/try/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/SakshamSehrawet/try/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/SakshamSehrawet/try/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/SakshamSehrawet/try/deployments',
#       'created_at': '2020-02-27T05:48:31Z',
#       'updated_at': '2020-02-27T06:13:25Z',
#       'pushed_at': '2020-02-27T06:13:46Z',
#       'git_url': 'git://github.com/SakshamSehrawet/try.git',
#       'ssh_url': 'git@github.com:SakshamSehrawet/try.git',
#       'clone_url': 'https://github.com/SakshamSehrawet/try.git',
#       'svn_url': 'https://github.com/SakshamSehrawet/try',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'SakshamSehrawet:master',
#      'ref': 'master',
#      'sha': '74daf66dcc14ae114d51f2b336e547c48dccc0ac',
#      'user': {'login': 'SakshamSehrawet',
#       'id': 24732526,
#       'node_id': 'MDQ6VXNlcjI0NzMyNTI2',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/24732526?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SakshamSehrawet',
#       'html_url': 'https://github.com/SakshamSehrawet',
#       'followers_url': 'https://api.github.com/users/SakshamSehrawet/followers',
#       'following_url': 'https://api.github.com/users/SakshamSehrawet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SakshamSehrawet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SakshamSehrawet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SakshamSehrawet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SakshamSehrawet/orgs',
#       'repos_url': 'https://api.github.com/users/SakshamSehrawet/repos',
#       'events_url': 'https://api.github.com/users/SakshamSehrawet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SakshamSehrawet/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 243441482,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDM0NDE0ODI=',
#       'name': 'try',
#       'full_name': 'SakshamSehrawet/try',
#       'private': False,
#       'owner': {'login': 'SakshamSehrawet',
#        'id': 24732526,
#        'node_id': 'MDQ6VXNlcjI0NzMyNTI2',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/24732526?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SakshamSehrawet',
#        'html_url': 'https://github.com/SakshamSehrawet',
#        'followers_url': 'https://api.github.com/users/SakshamSehrawet/followers',
#        'following_url': 'https://api.github.com/users/SakshamSehrawet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SakshamSehrawet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SakshamSehrawet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SakshamSehrawet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SakshamSehrawet/orgs',
#        'repos_url': 'https://api.github.com/users/SakshamSehrawet/repos',
#        'events_url': 'https://api.github.com/users/SakshamSehrawet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SakshamSehrawet/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SakshamSehrawet/try',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/SakshamSehrawet/try',
#       'forks_url': 'https://api.github.com/repos/SakshamSehrawet/try/forks',
#       'keys_url': 'https://api.github.com/repos/SakshamSehrawet/try/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SakshamSehrawet/try/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SakshamSehrawet/try/teams',
#       'hooks_url': 'https://api.github.com/repos/SakshamSehrawet/try/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SakshamSehrawet/try/events',
#       'assignees_url': 'https://api.github.com/repos/SakshamSehrawet/try/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SakshamSehrawet/try/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SakshamSehrawet/try/tags',
#       'blobs_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SakshamSehrawet/try/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SakshamSehrawet/try/languages',
#       'stargazers_url': 'https://api.github.com/repos/SakshamSehrawet/try/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SakshamSehrawet/try/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SakshamSehrawet/try/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SakshamSehrawet/try/subscription',
#       'commits_url': 'https://api.github.com/repos/SakshamSehrawet/try/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SakshamSehrawet/try/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SakshamSehrawet/try/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SakshamSehrawet/try/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SakshamSehrawet/try/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SakshamSehrawet/try/merges',
#       'archive_url': 'https://api.github.com/repos/SakshamSehrawet/try/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/SakshamSehrawet/try/downloads',
#       'issues_url': 'https://api.github.com/repos/SakshamSehrawet/try/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/SakshamSehrawet/try/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/SakshamSehrawet/try/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/SakshamSehrawet/try/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/SakshamSehrawet/try/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/SakshamSehrawet/try/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/SakshamSehrawet/try/deployments',
#       'created_at': '2020-02-27T05:48:31Z',
#       'updated_at': '2020-02-27T06:13:25Z',
#       'pushed_at': '2020-02-27T06:13:46Z',
#       'git_url': 'git://github.com/SakshamSehrawet/try.git',
#       'ssh_url': 'git@github.com:SakshamSehrawet/try.git',
#       'clone_url': 'https://github.com/SakshamSehrawet/try.git',
#       'svn_url': 'https://github.com/SakshamSehrawet/try',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/4'},
#      'html': {'href': 'https://github.com/SakshamSehrawet/try/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/SakshamSehrawet/try/statuses/bf0050198a99e5bc256eb0d8c6478f2f4d49f8a7'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-27T06:13:47Z'},
#  {'id': '11622350699',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 9990676,
#    'login': 'Matrixbirds',
#    'display_login': 'Matrixbirds',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Matrixbirds',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9990676?'},
#   'repo': {'id': 127635647,
#    'name': 'AgoraIO-Usecase/eEducation',
#    'url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation'},
#   'payload': {'action': 'opened',
#    'number': 86,
#    'pull_request': {'url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/86',
#     'id': 380657359,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgwNjU3MzU5',
#     'html_url': 'https://github.com/AgoraIO-Usecase/eEducation/pull/86',
#     'diff_url': 'https://github.com/AgoraIO-Usecase/eEducation/pull/86.diff',
#     'patch_url': 'https://github.com/AgoraIO-Usecase/eEducation/pull/86.patch',
#     'issue_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/86',
#     'number': 86,
#     'state': 'open',
#     'locked': False,
#     'title': "fix. could't start video source on win7 chrome 80 or chrome 81 devices",
#     'user': {'login': 'Matrixbirds',
#      'id': 9990676,
#      'node_id': 'MDQ6VXNlcjk5OTA2NzY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/9990676?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Matrixbirds',
#      'html_url': 'https://github.com/Matrixbirds',
#      'followers_url': 'https://api.github.com/users/Matrixbirds/followers',
#      'following_url': 'https://api.github.com/users/Matrixbirds/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Matrixbirds/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Matrixbirds/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Matrixbirds/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Matrixbirds/orgs',
#      'repos_url': 'https://api.github.com/users/Matrixbirds/repos',
#      'events_url': 'https://api.github.com/users/Matrixbirds/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Matrixbirds/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-02-27T06:13:46Z',
#     'updated_at': '2020-02-27T06:13:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/86/commits',
#     'review_comments_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/86/comments',
#     'review_comment_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/86/comments',
#     'statuses_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/statuses/72ebeddb668bc67ade5c755dbf28d98ceb0a9e4f',
#     'head': {'label': 'AgoraIO-Usecase:hotfix/cameraId-default-value',
#      'ref': 'hotfix/cameraId-default-value',
#      'sha': '72ebeddb668bc67ade5c755dbf28d98ceb0a9e4f',
#      'user': {'login': 'AgoraIO-Usecase',
#       'id': 41784742,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNzg0NzQy',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/41784742?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AgoraIO-Usecase',
#       'html_url': 'https://github.com/AgoraIO-Usecase',
#       'followers_url': 'https://api.github.com/users/AgoraIO-Usecase/followers',
#       'following_url': 'https://api.github.com/users/AgoraIO-Usecase/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AgoraIO-Usecase/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AgoraIO-Usecase/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AgoraIO-Usecase/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AgoraIO-Usecase/orgs',
#       'repos_url': 'https://api.github.com/users/AgoraIO-Usecase/repos',
#       'events_url': 'https://api.github.com/users/AgoraIO-Usecase/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AgoraIO-Usecase/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 127635647,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjc2MzU2NDc=',
#       'name': 'eEducation',
#       'full_name': 'AgoraIO-Usecase/eEducation',
#       'private': False,
#       'owner': {'login': 'AgoraIO-Usecase',
#        'id': 41784742,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNzg0NzQy',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/41784742?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AgoraIO-Usecase',
#        'html_url': 'https://github.com/AgoraIO-Usecase',
#        'followers_url': 'https://api.github.com/users/AgoraIO-Usecase/followers',
#        'following_url': 'https://api.github.com/users/AgoraIO-Usecase/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AgoraIO-Usecase/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AgoraIO-Usecase/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AgoraIO-Usecase/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AgoraIO-Usecase/orgs',
#        'repos_url': 'https://api.github.com/users/AgoraIO-Usecase/repos',
#        'events_url': 'https://api.github.com/users/AgoraIO-Usecase/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AgoraIO-Usecase/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/AgoraIO-Usecase/eEducation',
#       'description': 'e-education solutions(Agora Reference Design)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation',
#       'forks_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/forks',
#       'keys_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/teams',
#       'hooks_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/events',
#       'assignees_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/tags',
#       'blobs_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/languages',
#       'stargazers_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/subscription',
#       'commits_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/merges',
#       'archive_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/downloads',
#       'issues_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/deployments',
#       'created_at': '2018-04-01T14:17:04Z',
#       'updated_at': '2020-02-27T05:02:45Z',
#       'pushed_at': '2020-02-27T06:11:53Z',
#       'git_url': 'git://github.com/AgoraIO-Usecase/eEducation.git',
#       'ssh_url': 'git@github.com:AgoraIO-Usecase/eEducation.git',
#       'clone_url': 'https://github.com/AgoraIO-Usecase/eEducation.git',
#       'svn_url': 'https://github.com/AgoraIO-Usecase/eEducation',
#       'homepage': '',
#       'size': 83581,
#       'stargazers_count': 90,
#       'watchers_count': 90,
#       'language': 'Objective-C',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 54,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 15,
#       'license': None,
#       'forks': 54,
#       'open_issues': 15,
#       'watchers': 90,
#       'default_branch': 'master'}},
#     'base': {'label': 'AgoraIO-Usecase:master',
#      'ref': 'master',
#      'sha': '831d57093d8d2acf2b554f656f265599fb90730d',
#      'user': {'login': 'AgoraIO-Usecase',
#       'id': 41784742,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNzg0NzQy',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/41784742?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AgoraIO-Usecase',
#       'html_url': 'https://github.com/AgoraIO-Usecase',
#       'followers_url': 'https://api.github.com/users/AgoraIO-Usecase/followers',
#       'following_url': 'https://api.github.com/users/AgoraIO-Usecase/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AgoraIO-Usecase/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AgoraIO-Usecase/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AgoraIO-Usecase/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AgoraIO-Usecase/orgs',
#       'repos_url': 'https://api.github.com/users/AgoraIO-Usecase/repos',
#       'events_url': 'https://api.github.com/users/AgoraIO-Usecase/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AgoraIO-Usecase/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 127635647,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjc2MzU2NDc=',
#       'name': 'eEducation',
#       'full_name': 'AgoraIO-Usecase/eEducation',
#       'private': False,
#       'owner': {'login': 'AgoraIO-Usecase',
#        'id': 41784742,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNzg0NzQy',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/41784742?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AgoraIO-Usecase',
#        'html_url': 'https://github.com/AgoraIO-Usecase',
#        'followers_url': 'https://api.github.com/users/AgoraIO-Usecase/followers',
#        'following_url': 'https://api.github.com/users/AgoraIO-Usecase/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AgoraIO-Usecase/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AgoraIO-Usecase/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AgoraIO-Usecase/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AgoraIO-Usecase/orgs',
#        'repos_url': 'https://api.github.com/users/AgoraIO-Usecase/repos',
#        'events_url': 'https://api.github.com/users/AgoraIO-Usecase/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AgoraIO-Usecase/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/AgoraIO-Usecase/eEducation',
#       'description': 'e-education solutions(Agora Reference Design)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation',
#       'forks_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/forks',
#       'keys_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/teams',
#       'hooks_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/events',
#       'assignees_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/tags',
#       'blobs_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/languages',
#       'stargazers_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/subscription',
#       'commits_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/merges',
#       'archive_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/downloads',
#       'issues_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/deployments',
#       'created_at': '2018-04-01T14:17:04Z',
#       'updated_at': '2020-02-27T05:02:45Z',
#       'pushed_at': '2020-02-27T06:11:53Z',
#       'git_url': 'git://github.com/AgoraIO-Usecase/eEducation.git',
#       'ssh_url': 'git@github.com:AgoraIO-Usecase/eEducation.git',
#       'clone_url': 'https://github.com/AgoraIO-Usecase/eEducation.git',
#       'svn_url': 'https://github.com/AgoraIO-Usecase/eEducation',
#       'homepage': '',
#       'size': 83581,
#       'stargazers_count': 90,
#       'watchers_count': 90,
#       'language': 'Objective-C',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 54,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 15,
#       'license': None,
#       'forks': 54,
#       'open_issues': 15,
#       'watchers': 90,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/86'},
#      'html': {'href': 'https://github.com/AgoraIO-Usecase/eEducation/pull/86'},
#      'issue': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/86'},
#      'comments': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/issues/86/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/86/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/pulls/86/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/AgoraIO-Usecase/eEducation/statuses/72ebeddb668bc67ade5c755dbf28d98ceb0a9e4f'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 47,
#     'deletions': 15,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-27T06:13:47Z',
#   'org': {'id': 41784742,
#    'login': 'AgoraIO-Usecase',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AgoraIO-Usecase',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41784742?'}},
#  {'id': '11622350689',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 29282,
#    'login': 'tkf',
#    'display_login': 'tkf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tkf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29282?'},
#   'repo': {'id': 58931685,
#    'name': 'JuliaArrays/StaticArrays.jl',
#    'url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl/issues/744',
#     'repository_url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl',
#     'labels_url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl/issues/744/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl/issues/744/comments',
#     'events_url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl/issues/744/events',
#     'html_url': 'https://github.com/JuliaArrays/StaticArrays.jl/issues/744',
#     'id': 568678401,
#     'node_id': 'MDU6SXNzdWU1Njg2Nzg0MDE=',
#     'number': 744,
#     'title': "Broadcast of SArray with Array gives Array but we'd like SArray",
#     'user': {'login': 'c42f',
#      'id': 601473,
#      'node_id': 'MDQ6VXNlcjYwMTQ3Mw==',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/601473?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/c42f',
#      'html_url': 'https://github.com/c42f',
#      'followers_url': 'https://api.github.com/users/c42f/followers',
#      'following_url': 'https://api.github.com/users/c42f/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/c42f/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/c42f/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/c42f/subscriptions',
#      'organizations_url': 'https://api.github.com/users/c42f/orgs',
#      'repos_url': 'https://api.github.com/users/c42f/repos',
#      'events_url': 'https://api.github.com/users/c42f/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/c42f/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 377134530,
#       'node_id': 'MDU6TGFiZWwzNzcxMzQ1MzA=',
#       'url': 'https://api.github.com/repos/JuliaArrays/StaticArrays.jl/labels/enhancement',
#       'name': 'enhancement',
#       'color': 'f9adea',
#       'default': True,
#       'description': 'features and feature requests'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 13,
#     'created_at': '2020-02-21T01:18:55Z',
#     'updated_at': '2020-02-27T06:13:47Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
# ...
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c2d8bbe8fa456e1954d8025b51be9e4a3ed95934',
#    'before': '3fbad51b7dfb649a1710f39082e1371bc09ae9f1',
#    'commits': [{'sha': 'c2d8bbe8fa456e1954d8025b51be9e4a3ed95934',
#      'author': {'email': '61533649+AmandaQuest@users.noreply.github.com',
#       'name': 'AmandaQuest'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AmandaQuest/dragon-quest-of-the-stars-cheats-iOS-hack-gems/commits/c2d8bbe8fa456e1954d8025b51be9e4a3ed95934'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350650',
#   'type': 'PushEvent',
#   'actor': {'id': 46730874,
#    'login': 'Shirwarsame',
#    'display_login': 'Shirwarsame',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shirwarsame',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46730874?'},
#   'repo': {'id': 233734497,
#    'name': 'mohanadarafe/GuideMe',
#    'url': 'https://api.github.com/repos/mohanadarafe/GuideMe'},
#   'payload': {'push_id': 4688360673,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/shirwa',
#    'head': 'f254c07ce5ac50b10d95c804c11dc3efa2fb25fa',
#    'before': '5daf107bde7eab053347c2ac866806172f66451a',
#    'commits': [{'sha': 'f254c07ce5ac50b10d95c804c11dc3efa2fb25fa',
#      'author': {'email': 'shirwarsame@gmail.com', 'name': 'Shirwa Warsame'},
#      'message': 'converting LoyolaData into arraylist',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mohanadarafe/GuideMe/commits/f254c07ce5ac50b10d95c804c11dc3efa2fb25fa'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350638',
#   'type': 'PushEvent',
#   'actor': {'id': 57948503,
#    'login': 'pitinun',
#    'display_login': 'pitinun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pitinun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57948503?'},
#   'repo': {'id': 223877356,
#    'name': 'sut62/team09',
#    'url': 'https://api.github.com/repos/sut62/team09'},
#   'payload': {'push_id': 4688360664,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '604afaf80e89d68e0ea73977ab877189d9c77262',
#    'before': '90030b98bd8afa0014e1a0f595e32dbe02eb098c',
#    'commits': [{'sha': 'c89a8fe1f1328829d2302899353619c82796e07c',
#      'author': {'email': 'b5904778@g.sut.ac.th', 'name': 'pitinun'},
#      'message': 'close #207 Add test and entity Diagnose',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sut62/team09/commits/c89a8fe1f1328829d2302899353619c82796e07c'},
#     {'sha': '604afaf80e89d68e0ea73977ab877189d9c77262',
#      'author': {'email': 'b5904778@g.sut.ac.th', 'name': 'pitinun'},
#      'message': "Merge branch 'issue-207'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sut62/team09/commits/604afaf80e89d68e0ea73977ab877189d9c77262'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z',
#   'org': {'id': 58115231,
#    'login': 'sut62',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sut62',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58115231?'}},
#  {'id': '11622350639',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 243441482,
#    'name': 'SakshamSehrawet/try',
#    'url': 'https://api.github.com/repos/SakshamSehrawet/try'},
#   'payload': {'ref': 'dependabot/pip/requests-2.20.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350633',
#   'type': 'WatchEvent',
#   'actor': {'id': 22090863,
#    'login': 'zkHuang',
#    'display_login': 'zkHuang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zkHuang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22090863?'},
#   'repo': {'id': 61980073,
#    'name': 'hackware1993/MagicIndicator',
#    'url': 'https://api.github.com/repos/hackware1993/MagicIndicator'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350612',
#   'type': 'PushEvent',
#   'actor': {'id': 43028733,
#    'login': 'StitchDex',
#    'display_login': 'StitchDex',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StitchDex',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43028733?'},
#   'repo': {'id': 243429052,
#    'name': 'StitchDex/StitchDex.github.io',
#    'url': 'https://api.github.com/repos/StitchDex/StitchDex.github.io'},
#   'payload': {'push_id': 4688360649,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6acc5d147bd3c18f31ec1ca89ffa8ebfbd9410b7',
#    'before': '2d3d5e3f06498a2e4fcf574a0fefd6bbb25a4dfb',
#    'commits': [{'sha': '6acc5d147bd3c18f31ec1ca89ffa8ebfbd9410b7',
#      'author': {'email': '43028733+StitchDex@users.noreply.github.com',
#       'name': 'StitchDex'},
#      'message': 'Update navigation.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/StitchDex/StitchDex.github.io/commits/6acc5d147bd3c18f31ec1ca89ffa8ebfbd9410b7'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350615',
#   'type': 'PushEvent',
#   'actor': {'id': 9811142,
#    'login': 'Maximization',
#    'display_login': 'Maximization',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Maximization',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9811142?'},
#   'repo': {'id': 243208405,
#    'name': 'Maximization/autodeploy-docker',
#    'url': 'https://api.github.com/repos/Maximization/autodeploy-docker'},
#   'payload': {'push_id': 4688360657,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd8dbedc55bfb3a3273092a80cd9389ac309f83f0',
#    'before': '7b6c976714c29f54ed769c53156727e8fa9de383',
#    'commits': [{'sha': 'd8dbedc55bfb3a3273092a80cd9389ac309f83f0',
#      'author': {'email': 'maximorl@gmail.com', 'name': 'Maxim Orlov'},
#      'message': 'Checkout code before deploying in CI job',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Maximization/autodeploy-docker/commits/d8dbedc55bfb3a3273092a80cd9389ac309f83f0'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350609',
#   'type': 'PushEvent',
#   'actor': {'id': 117777,
#    'login': 'wez',
#    'display_login': 'wez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117777?'},
#   'repo': {'id': 120568143,
#    'name': 'wez/wezterm',
#    'url': 'https://api.github.com/repos/wez/wezterm'},
#   'payload': {'push_id': 4688360647,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'ab03147bd97e919e5dc9a2d0ca78a27b8d052ca6',
#    'before': '54047e357a94bbe7d6c1b41eb325f75951976b22',
#    'commits': [{'sha': 'b46d2f054a6107e3699419099f60190560143210',
#      'author': {'email': 'wez@wezfurlong.org', 'name': 'Wez Furlong'},
#      'message': 'mux: unset misc env vars when starting the mux server',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wez/wezterm/commits/b46d2f054a6107e3699419099f60190560143210'},
#     {'sha': 'ab03147bd97e919e5dc9a2d0ca78a27b8d052ca6',
#      'author': {'email': 'wez@wezfurlong.org', 'name': 'Wez Furlong'},
#      'message': 'config: we can now read ~/.wezterm.lua\n\nThis allows for slightly more fancy configuration in the future, but for\nnow it is rather simple: your lua script returns a configuration struct\nwith the same shape as that from the TOML file.\n\nA `wezterm` module is provided to the script that provides some\nconstants to help understand the environment in which wezterm\nis running.\n\nI want to add some helpers that make setting up the fonts feel less\nweird (lots of nesting in the data model makes this weird).\n\nThe ability to conditionally construct configuration is powerful\nand helps to address the broader request in\nrefs: https://github.com/wez/wezterm/issues/152\n\nAn example config looks like this:\n\n```lua\nlocal wezterm = require \'wezterm\';\n\nprint(wezterm.config_dir);\nprint(wezterm.executable_dir);\nwezterm.log_error("w00t! running " .. wezterm.version\n  .. " on " .. wezterm.target_triple ..  " " .. wezterm.home_dir);\n\nreturn {\n  enable_scroll_bar = true,\n  enable_tab_bar = true,\n  ratelimit_output_bytes_per_second = 400000,\n  scrollback_lines = 350000,\n  font_dirs = {".dotfiles/fonts"},\n\n  window_padding = {\n    left = 2,\n    bottom = 2,\n  },\n\n  font = {\n    font = {{\n      family = "Operator Mono SSm Lig Medium",\n    }},\n  },\n\n  unix_domains = {\n    {\n      name = "unix",\n    }\n  },\n\n  ssh_domains = {\n    {\n      name = "localhost",\n      remote_address = "localhost",\n      username = "wez",\n    },\n  },\n\n  tls_clients = {\n    {\n      name = "cubetls",\n      remote_address = "cube-localdomain:8080",\n      bootstrap_via_ssh = "cube-localdomain",\n    },\n  },\n\n  tls_servers = {\n    {\n      bind_address = "192.168.1.8:8080",\n    },\n  },\n\n  hyperlink_rules = {\n    {\n      regex = "\\\\b\\\\w+://(?:[\\\\w.-]+)\\\\.[a-z]{2,15}\\\\S*\\\\b",\n      format = "$0",\n    },\n  },\n\n  font_rules= {\n    {\n      italic = true,\n      font = {\n        font = {{\n          family = "Operator Mono SSm Lig Medium Italic",\n        }}\n      },\n    },\n\n    {\n      italic = true,\n      intensity = "Bold",\n      font = {\n        font = {{\n          family = "Operator Mono SSm Lig Book Italic",\n        }}\n      },\n    },\n\n    {\n      intensity = "Bold",\n      font = {\n        foreground = "tomato",\n        font = {{\n          family = "Operator Mono SSm Lig Bold",\n        }}\n      },\n    },\n\n    {\n      intensity = "Half",\n      font = {\n        font = {{\n          family = "Operator Mono SSm Lig Light",\n        }}\n      },\n    },\n  },\n}\n```',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wez/wezterm/commits/ab03147bd97e919e5dc9a2d0ca78a27b8d052ca6'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'},
#  {'id': '11622350611',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 102737539,
#    'name': 'Lombiq/Hastlayer-SDK',
#    'url': 'https://api.github.com/repos/Lombiq/Hastlayer-SDK'},
#   'payload': {'push_id': 4688360646,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/HAST-121',
#    'head': 'cb05633b43613299c978c5ef306f2f4451febe19',
#    'before': 'cb05633b43613299c978c5ef306f2f4451febe19',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11622350604',
#   'type': 'IssuesEvent',
#   'actor': {'id': 57948503,
#    'login': 'pitinun',
#    'display_login': 'pitinun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pitinun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57948503?'},
#   'repo': {'id': 223877356,
#    'name': 'sut62/team09',
#    'url': 'https://api.github.com/repos/sut62/team09'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/sut62/team09/issues/207',
#     'repository_url': 'https://api.github.com/repos/sut62/team09',
#     'labels_url': 'https://api.github.com/repos/sut62/team09/issues/207/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/sut62/team09/issues/207/comments',
#     'events_url': 'https://api.github.com/repos/sut62/team09/issues/207/events',
#     'html_url': 'https://github.com/sut62/team09/issues/207',
#     'id': 571843274,
#     'node_id': 'MDU6SXNzdWU1NzE4NDMyNzQ=',
#     'number': 207,
#     'title': 'ทำการแก้ไข test และ entity ของ Diagnose',
#     'user': {'login': 'pitinun',
#      'id': 57948503,
#      'node_id': 'MDQ6VXNlcjU3OTQ4NTAz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/57948503?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pitinun',
#      'html_url': 'https://github.com/pitinun',
#      'followers_url': 'https://api.github.com/users/pitinun/followers',
#      'following_url': 'https://api.github.com/users/pitinun/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pitinun/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pitinun/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pitinun/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pitinun/orgs',
#      'repos_url': 'https://api.github.com/users/pitinun/repos',
#      'events_url': 'https://api.github.com/users/pitinun/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pitinun/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1700491798,
#       'node_id': 'MDU6TGFiZWwxNzAwNDkxNzk4',
#       'url': 'https://api.github.com/repos/sut62/team09/labels/task',
#       'name': 'task',
#       'color': 'adf279',
#       'default': False,
#       'description': 'งานที่แบ่งจาก user story'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-02-27T06:01:30Z',
#     'updated_at': '2020-02-27T06:13:45Z',
#     'closed_at': '2020-02-27T06:13:45Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': ''}},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z',
#   'org': {'id': 58115231,
#    'login': 'sut62',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sut62',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58115231?'}},
#  {'id': '11622350601',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46594794,
#    'name': 'Lombiq/Associativy-Web-Services',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Web-Services'},
#   'payload': {'push_id': 4688360642,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev',
#    'head': '0cd803add9673a525e405901cbe56c63c6aef490',
#    'before': '0cd803add9673a525e405901cbe56c63c6aef490',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11622350597',
#   'type': 'PushEvent',
#   'actor': {'id': 46825838,
#    'login': 'rebekahewaller',
#    'display_login': 'rebekahewaller',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rebekahewaller',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46825838?'},
#   'repo': {'id': 236618005,
#    'name': 'rebekahewaller/be-423-523-project',
#    'url': 'https://api.github.com/repos/rebekahewaller/be-423-523-project'},
#   'payload': {'push_id': 4688360643,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/lettuce',
#    'head': '9667411e691fee28858cc5d158413f17a4d136ee',
#    'before': 'ee7b2e12a67556b4e35c606235f90c26c8ed6cdf',
#    'commits': [{'sha': '9667411e691fee28858cc5d158413f17a4d136ee',
#      'author': {'email': '46825838+rebekahewaller@users.noreply.github.com',
#       'name': 'rebekahewaller'},
#      'message': 'Delete Articles for Modeling.docx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rebekahewaller/be-423-523-project/commits/9667411e691fee28858cc5d158413f17a4d136ee'}]},
#   'public': True,
#   'created_at': '2020-02-27T06:13:46Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
o = requests.get("http://httpbin.org/get")
print(json.loads(o.text))
print("-------------------------------")
r = requests.get("http://httpbin.org/get", params=payload)
print(json.loads(r.text))
# Out:
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.22.0', 'X-Amzn-Trace-Id': 'Root=1-5e575f7e-1c583eb96e2436f72f726cb0'}, 'origin': '61.216.7.241', 'url': 'http://httpbin.org/get'}
# -------------------------------
# {'args': {'key1': 'value1', 'key2': 'value2'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.22.0', 'X-Amzn-Trace-Id': 'Root=1-5e575f7e-96a79604095c6ee4920d6dc0'}, 'origin': '61.216.7.241', 'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e575f8f-180048400b0d84d1ad80869c'},
#  'json': None,
#  'origin': '61.216.7.241',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
